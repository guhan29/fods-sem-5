# %%
import numpy as np
import pandas as pd
d = pd.DataFrame({
    "Item": ['Item0', 'Item0', 'Item1', 'Item1'],
    "CType":['Gold', 'Bronze', 'Gold', 'Silver'],
    "USD":  ['1$', '2$', '3$', '4$'],
    "EU":  ['1€', '2€', '3€', '4€']
})

# %%
d
# Out:
#     Item   CType USD  EU
# 0  Item0    Gold  1$  1€
# 1  Item0  Bronze  2$  2€
# 2  Item1    Gold  3$  3€
# 3  Item1  Silver  4$  4€

# %% [markdown]
# ## pivot

# %%
p = d.pivot(index='Item',columns='CType',values='USD')
p
# Out:
# CType Bronze Gold Silver
# Item
# Item0     2$   1$    NaN
# Item1    NaN   3$     4$

# %%
print(p[p.index=="Item0"].Gold.values)
# Out:
# ['1$']

# %%
print(p[p.index=="Item0"].Silver.values)
# Out:
# [nan]

# %%
p = d.pivot(index='Item',columns='CType')
p
# Out:
#          USD                 EU
# CType Bronze Gold Silver Bronze Gold Silver
# Item
# Item0     2$   1$    NaN     2€   1€    NaN
# Item1    NaN   3$     4$    NaN   3€     4€

# %%
print(p[p.index=="Item1"].USD.Bronze.values)
print(p[p.index=="Item0"].EU.Gold.values)
print(p[p.index=="Item1"].EU.Silver.values)
# Out:
# [nan]
# ['1€']
# ['4€']

# %%
type(p)
# Out:
# pandas.core.frame.DataFrame

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###  -> when using pivot make sure the attributes are unique and don't contain duplicate entries

# %%
d = pd.DataFrame({
    "Item": ['Item0', 'Item0', 'Item0', 'Item1'],
    "CType":['Gold', 'Bronze', 'Gold', 'Silver'],
    "USD":  [1, 2, 3, 4],
    "EU":  [1, 2, 3, 4]})

# %% [markdown]
# ### -> deliberately put error generating statement

# %%
p = d.pivot(index="Item",columns="CType")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-073154595ab4> in <module>
# ----> 1 p = d.pivot(index="Item",columns="CType")
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5932         from pandas.core.reshape.pivot import pivot
#    5933
# -> 5934         return pivot(self, index=index, columns=columns, values=values)
#    5935
#    5936     _shared_docs[
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    6391         from pandas.core.reshape.reshape import unstack
#    6392
# -> 6393         return unstack(self, level, fill_value)
#    6394
#    6395     _shared_docs[
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     410     if isinstance(obj, DataFrame):
#     411         if isinstance(obj.index, MultiIndex):
# --> 412             return _unstack_frame(obj, level, fill_value=fill_value)
#     413         else:
#     414             return obj.T.stack(dropna=False)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
#     440             value_columns=obj.columns,
#     441             fill_value=fill_value,
# --> 442             constructor=obj._constructor,
#     443         )
#     444         return unstacker.get_result()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     140
#     141         self._make_sorted_values_labels()
# --> 142         self._make_selectors()
#     143
#     144     def _make_sorted_values_labels(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     178
#     179         if mask.sum() < len(self.index):
# --> 180             raise ValueError("Index contains duplicate entries, " "cannot reshape")
#     181
#     182         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
d = pd.DataFrame({
    "Item": ['Item0', 'Item0', 'Item0', 'Item1'],
    "CType":['Gold', 'Bronze', 'Gold', 'Silver'],
    "USD":  [1, 2, 3, 4],
    "EU":  [1.1, 2.2, 3.3, 4.4]})
d
# Out:
#     Item   CType  USD   EU
# 0  Item0    Gold    1  1.1
# 1  Item0  Bronze    2  2.2
# 2  Item0    Gold    3  3.3
# 3  Item1  Silver    4  4.4

# %%
p = d.pivot_table(index="Item",columns="CType",values="USD")
p
# Out:
# CType  Bronze  Gold  Silver
# Item
# Item0     2.0   2.0     NaN
# Item1     NaN   NaN     4.0

# %%
p = d.pivot_table(index="Item",columns="CType",values="USD",aggfunc=np.min)
p
# Out:
# CType  Bronze  Gold  Silver
# Item
# Item0     2.0   1.0     NaN
# Item1     NaN   NaN     4.0

# %%
p = d.pivot_table(index="Item",columns="CType",values="USD",aggfunc=np.max)
p
# Out:
# CType  Bronze  Gold  Silver
# Item
# Item0     2.0   3.0     NaN
# Item1     NaN   NaN     4.0

# %%
p = d.pivot_table(index="Item",columns="CType",values="USD",aggfunc="mean")
p #another way to represent aggfunc
# Out:
# CType  Bronze  Gold  Silver
# Item
# Item0     2.0   2.0     NaN
# Item1     NaN   NaN     4.0

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index="city",columns="date",values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df_val2 = df.pivot(index="date",columns="city")
df_val2.index.name=None
df_val2.columns.name=None
df_val2.columns.name = None
df_val2
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %% [markdown]
# ### -> eliminating column and row titles

# %%
df_val = df.pivot(index="city",columns="date",values="humidity")
df_val.index.name=None
df_val
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df_val.columns.name=None
df_val
# Out:
#           5/1/2017  5/2/2017  5/3/2017
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df = pd.read_csv('weather2.csv')
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %% [markdown]
# # the below cell will show an error

# %%
df.pivot(index="city",columns="date")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-abf8baa86fc6> in <module>
# ----> 1 df.pivot(index="city",columns="date")
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5932         from pandas.core.reshape.pivot import pivot
#    5933
# -> 5934         return pivot(self, index=index, columns=columns, values=values)
#    5935
#    5936     _shared_docs[
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    6391         from pandas.core.reshape.reshape import unstack
#    6392
# -> 6393         return unstack(self, level, fill_value)
#    6394
#    6395     _shared_docs[
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     410     if isinstance(obj, DataFrame):
#     411         if isinstance(obj.index, MultiIndex):
# --> 412             return _unstack_frame(obj, level, fill_value=fill_value)
#     413         else:
#     414             return obj.T.stack(dropna=False)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
#     440             value_columns=obj.columns,
#     441             fill_value=fill_value,
# --> 442             constructor=obj._constructor,
#     443         )
#     444         return unstacker.get_result()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     140
#     141         self._make_sorted_values_labels()
# --> 142         self._make_selectors()
#     143
#     144     def _make_sorted_values_labels(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     178
#     179         if mask.sum() < len(self.index):
# --> 180             raise ValueError("Index contains duplicate entries, " "cannot reshape")
#     181
#     182         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index="city",columns="date",margins=True,aggfunc=np.min)
# Out:
#          humidity              temperature
# date     5/1/2017 5/2/2017 All    5/1/2017 5/2/2017 All
# city
# mumbai         80       26  26          75       80  75
# new york       54       60  54          61       70  61
# All            54       26  26          61       70  61

# %% [markdown]
# ### pivot converts a longer dataframe to a broader dataframe
#
#
# #df = pd.read_csv(weather3.csv)

# %% [markdown]
# ### melt in pandas is the exact opposite of pivot

# %%
df = pd.read_csv('weather4.csv')
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df1 = pd.melt(df,id_vars=["day"])
df1
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
melted = pd.melt(df,id_vars=['day'],var_name='city',value_name='temperature')
melted
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
df_unmelted = melted.pivot(index="day",columns="city")
# df_unmelted.columns.name = None
# df_unmelted.index.name = None
df_unmelted
# Out:
#           temperature
# city           berlin chennai chicago
# day
# Friday             30      83      30
# Monday             41      75      32
# Saturday           45      81      20
# Sunday             47      77      25
# Thursday           38      82      22
# Tuesday            43      77      30
# Wednesday          45      75      28

# %%
df_unmelted.columns = df_unmelted.columns.droplevel()
df_unmelted
# Out:
# city       berlin  chennai  chicago
# day
# Friday         30       83       30
# Monday         41       75       32
# Saturday       45       81       20
# Sunday         47       77       25
# Thursday       38       82       22
# Tuesday        43       77       30
# Wednesday      45       75       28

# %%
df_unmelted.columns.name = None
df_unmelted.index.name = None
df_unmelted
# Out:
#            berlin  chennai  chicago
# Friday         30       83       30
# Monday         41       75       32
# Saturday       45       81       20
# Sunday         47       77       25
# Thursday       38       82       22
# Tuesday        43       77       30
# Wednesday      45       75       28

# %%
df_unmelted.reset_index(inplace=True)
df_unmelted = df_unmelted.rename(columns={'index':'day'})
df_unmelted
# Out:
#          day  berlin  chennai  chicago
# 0     Friday      30       83       30
# 1     Monday      41       75       32
# 2   Saturday      45       81       20
# 3     Sunday      47       77       25
# 4   Thursday      38       82       22
# 5    Tuesday      43       77       30
# 6  Wednesday      45       75       28

# %%
df = pd.read_csv('http://files.zillowstatic.com/research/public_v2/invt_fs/Metro_invt_fs_uc_sfrcondo_smoothed_month.csv')
df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 116    394586       504                       Faribault, MN        Msa
# 117    394309       527                       Albemarle, NC        Msa
# 118    394742       595                       Kerrville, TX        Msa
# 119    395091       641                     Shelbyville, TN        Msa
# 120    395230       672                      Wilmington, OH        Msa
#
#     StateName  2017-10-31  2017-11-30  2017-12-31  2018-01-31  2018-02-28  \
# 0         NaN   1660657.0   1600667.0   1526619.0   1491269.0   1429228.0
# 1          NY     82960.0     79438.0     75253.0     73101.0     71028.0
# 2          CA     25402.0     23886.0     22022.0     21475.0     20597.0
# 3          IL     47461.0     44752.0     41690.0     40113.0     37662.0
# 4          TX     29470.0     28086.0     26489.0     25581.0     24078.0
# ..        ...         ...         ...         ...         ...         ...
# 116        MN         NaN         NaN         NaN         NaN         NaN
# 117        NC       253.0       249.0       243.0       240.0       235.0
# 118        TX       399.0       397.0       387.0       377.0       366.0
# 119        TN       196.0       199.0       199.0       201.0       201.0
# 120        OH         NaN         NaN         NaN         NaN         NaN
#
#      ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  2020-01-31  \
# 0    ...   1823377.0   1802709.0   1738814.0   1639272.0   1551623.0
# 1    ...     97582.0     95730.0     92144.0     87172.0     81859.0
# 2    ...     31583.0     30964.0     29213.0     26506.0     24219.0
# 3    ...     54670.0     54034.0     51835.0     48065.0     44492.0
# 4    ...     39912.0     39293.0     37764.0     35558.0     33720.0
# ..   ...         ...         ...         ...         ...         ...
# 116  ...       306.0       304.0       291.0       270.0       241.0
# 117  ...       261.0       267.0       263.0       247.0       232.0
# 118  ...       419.0       421.0       410.0       393.0       381.0
# 119  ...       239.0       252.0       256.0       260.0       261.0
# 120  ...       154.0       158.0       154.0       148.0       137.0
#
#      2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 0     1474343.0   1453944.0   1449684.0   1471201.0   1488009.0
# 1       77974.0     77474.0     75680.0     75283.0     76256.0
# 2       22403.0     21621.0     21502.0     22089.0     22858.0
# 3       42068.0     41655.0     41647.0     42661.0     43537.0
# 4       32350.0     31944.0     31991.0     33013.0     33720.0
# ..          ...         ...         ...         ...         ...
# 116       224.0       222.0       228.0       250.0       263.0
# 117       215.0       208.0       209.0       208.0       203.0
# 118       372.0       370.0       367.0       368.0       373.0
# 119       249.0       242.0       241.0       240.0       238.0
# 120       126.0       117.0       113.0       105.0       105.0
#
# [121 rows x 38 columns]

# %%
df_new = pd.melt(frame=df,id_vars=['RegionID','SizeRank','RegionName','RegionType','StateName'],var_name='year_val',value_name='count')
df_new
# Out:
#       RegionID  SizeRank                          RegionName RegionType  \
# 0       102001         0                       United States    Country
# 1       394913         1                        New York, NY        Msa
# 2       753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3       394463         3                         Chicago, IL        Msa
# 4       394514         4               Dallas-Fort Worth, TX        Msa
# ...        ...       ...                                 ...        ...
# 3988    394586       504                       Faribault, MN        Msa
# 3989    394309       527                       Albemarle, NC        Msa
# 3990    394742       595                       Kerrville, TX        Msa
# 3991    395091       641                     Shelbyville, TN        Msa
# 3992    395230       672                      Wilmington, OH        Msa
#
#      StateName    year_val      count
# 0          NaN  2017-10-31  1660657.0
# 1           NY  2017-10-31    82960.0
# 2           CA  2017-10-31    25402.0
# 3           IL  2017-10-31    47461.0
# 4           TX  2017-10-31    29470.0
# ...        ...         ...        ...
# 3988        MN  2020-06-30      263.0
# 3989        NC  2020-06-30      203.0
# 3990        TX  2020-06-30      373.0
# 3991        TN  2020-06-30      238.0
# 3992        OH  2020-06-30      105.0
#
# [3993 rows x 7 columns]

# %%
df_new.shape
# Out:
# (3993, 7)

# %%
df_new.dtypes
# Out:
# RegionID        int64
# SizeRank        int64
# RegionName     object
# RegionType     object
# StateName      object
# year_val       object
# count         float64
# dtype: object

# %%
df_new['year_val'].str.split('-').head()
# Out:
# 0    [2017, 10, 31]
# 1    [2017, 10, 31]
# 2    [2017, 10, 31]
# 3    [2017, 10, 31]
# 4    [2017, 10, 31]
# Name: year_val, dtype: object

# %%
df_new[['year','month','date']] = df_new['year_val'].str.split('-',expand=True)
df_new.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName    year_val      count  year month date
# 0       NaN  2017-10-31  1660657.0  2017    10   31
# 1        NY  2017-10-31    82960.0  2017    10   31
# 2        CA  2017-10-31    25402.0  2017    10   31
# 3        IL  2017-10-31    47461.0  2017    10   31
# 4        TX  2017-10-31    29470.0  2017    10   31

# %%
df_new.drop(columns=['year_val'],inplace=True,axis=1)

# %%
df_new['year'].astype('int')
df_new.dtypes
# Out:
# RegionID        int64
# SizeRank        int64
# RegionName     object
# RegionType     object
# StateName      object
# count         float64
# year           object
# month          object
# date           object
# dtype: object

# %%
df = pd.read_excel('stocks.xlsx',header=[0,1],index_col=[0])
df
#df.columns = df.columns.droplevel()
# Out:
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %% [markdown]
# ### -> stacks

# %%
df.stack(level=0)
# Out:
# Company                                   Facebook  Google  Microsoft
# 2017-06-05 Price                            155.00   955.0      66.00
#            Price to earnings ratio (P/E)     37.10    32.0      30.31
# 2017-06-06 Price                            150.00   987.0      69.00
#            Price to earnings ratio (P/E)     36.98    31.3      30.56
# 2017-06-07 Price                            153.00   963.0      62.00
#            Price to earnings ratio (P/E)     36.78    31.7      30.46
# 2017-06-08 Price                            155.00  1000.0      61.00
#            Price to earnings ratio (P/E)     36.11    31.2      30.11
# 2017-06-09 Price                            156.00  1012.0      66.00
#            Price to earnings ratio (P/E)     37.07    30.0      31.00

# %%
df.stack(1)
# Out:
#                       Price  Price to earnings ratio (P/E)
#            Company
# 2017-06-05 Facebook     155                          37.10
#            Google       955                          32.00
#            Microsoft     66                          30.31
# 2017-06-06 Facebook     150                          36.98
#            Google       987                          31.30
#            Microsoft     69                          30.56
# 2017-06-07 Facebook     153                          36.78
#            Google       963                          31.70
#            Microsoft     62                          30.46
# 2017-06-08 Facebook     155                          36.11
#            Google      1000                          31.20
#            Microsoft     61                          30.11
# 2017-06-09 Facebook     156                          37.07
#            Google      1012                          30.00
#            Microsoft     66                          31.00

# %%
df_stacked= df.stack(level=1)
df_stacked
# Out:
#                       Price  Price to earnings ratio (P/E)
#            Company
# 2017-06-05 Facebook     155                          37.10
#            Google       955                          32.00
#            Microsoft     66                          30.31
# 2017-06-06 Facebook     150                          36.98
#            Google       987                          31.30
#            Microsoft     69                          30.56
# 2017-06-07 Facebook     153                          36.78
#            Google       963                          31.70
#            Microsoft     62                          30.46
# 2017-06-08 Facebook     155                          36.11
#            Google      1000                          31.20
#            Microsoft     61                          30.11
# 2017-06-09 Facebook     156                          37.07
#            Google      1012                          30.00
#            Microsoft     66                          31.00

# %%
df_stacked.unstack(level=1)
# Out:
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %%
df = pd.read_excel('stocks_3_levels.xlsx',header=[0,1,2],index_col=[0])
df
# Out:
#         Price Ratios                                                        \
#                Price                  Price to earnings ratio (P/E)
# Company     Facebook Google Microsoft                      Facebook Google
# Q1 2016          155    955        66                         37.10   32.0
# Q2 2016          150    987        69                         36.98   31.3
# Q3 2016          153    963        62                         36.78   31.7
# Q4 2016          155   1000        61                         36.11   31.2
# Q1 2017          156   1012        66                         37.07   30.0
#
#                   Income Statement                                     \
#                          Net Sales                  Net Profit
# Company Microsoft         Facebook Google Microsoft   Facebook Google
# Q1 2016     30.31              2.6     20     18.70       0.80   5.43
# Q2 2016     30.56              3.1     22     21.30       0.97   5.89
# Q3 2016     30.46              4.3     24     21.45       1.20   6.10
# Q4 2016     30.11              6.7     26     21.88       1.67   6.50
# Q1 2017     31.00              8.1     31     22.34       2.03   6.40
#
#
#
# Company Microsoft
# Q1 2016      4.56
# Q2 2016      5.10
# Q3 2016      5.43
# Q4 2016      5.89
# Q1 2017      6.09

# %%
df_stacked = df.stack(level=2)
df_stacked
# Out:
#                   Income Statement           Price Ratios  \
#                         Net Profit Net Sales        Price
#         Company
# Q1 2016 Facebook              0.80      2.60          155
#         Google                5.43     20.00          955
#         Microsoft             4.56     18.70           66
# Q2 2016 Facebook              0.97      3.10          150
#         Google                5.89     22.00          987
#         Microsoft             5.10     21.30           69
# Q3 2016 Facebook              1.20      4.30          153
#         Google                6.10     24.00          963
#         Microsoft             5.43     21.45           62
# Q4 2016 Facebook              1.67      6.70          155
#         Google                6.50     26.00         1000
#         Microsoft             5.89     21.88           61
# Q1 2017 Facebook              2.03      8.10          156
#         Google                6.40     31.00         1012
#         Microsoft             6.09     22.34           66
#
#
#                   Price to earnings ratio (P/E)
#         Company
# Q1 2016 Facebook                          37.10
#         Google                            32.00
#         Microsoft                         30.31
# Q2 2016 Facebook                          36.98
#         Google                            31.30
#         Microsoft                         30.56
# Q3 2016 Facebook                          36.78
#         Google                            31.70
#         Microsoft                         30.46
# Q4 2016 Facebook                          36.11
#         Google                            31.20
#         Microsoft                         30.11
# Q1 2017 Facebook                          37.07
#         Google                            30.00
#         Microsoft                         31.00

# %%
df = pd.DataFrame([[0, 2], [3, 4]],
                                    index=['deer', 'monkey'],
                                    columns=['weight', 'height'])
df
# Out:
#         weight  height
# deer         0       2
# monkey       3       4

# %%
df = pd.read_csv('https://theunitedstates.io/congress-legislators/legislators-historical.csv')
df.head()
# Out:
#   last_name  first_name middle_name suffix nickname full_name    birthday  \
# 0   Bassett     Richard         NaN    NaN      NaN       NaN  1745-04-02
# 1     Bland  Theodorick         NaN    NaN      NaN       NaN  1742-03-21
# 2     Burke     Aedanus         NaN    NaN      NaN       NaN  1743-06-16
# 3   Carroll      Daniel         NaN    NaN      NaN       NaN  1730-07-22
# 4    Clymer      George         NaN    NaN      NaN       NaN  1739-03-16
#
#   gender type state  ...  opensecrets_id  lis_id fec_ids cspan_id govtrack_id  \
# 0      M  sen    DE  ...             NaN     NaN     NaN      NaN      401222
# 1      M  rep    VA  ...             NaN     NaN     NaN      NaN      401521
# 2      M  rep    SC  ...             NaN     NaN     NaN      NaN      402032
# 3      M  rep    MD  ...             NaN     NaN     NaN      NaN      402334
# 4      M  rep    PA  ...             NaN     NaN     NaN      NaN      402671
#
#   votesmart_id ballotpedia_id washington_post_id  icpsr_id  \
# 0          NaN            NaN                NaN     507.0
# 1          NaN            NaN                NaN     786.0
# 2          NaN            NaN                NaN    1260.0
# 3          NaN            NaN                NaN    1538.0
# 4          NaN            NaN                NaN    1859.0
#
#                      wikipedia_id
# 0    Richard Bassett (politician)
# 1  Theodorick Bland (congressman)
# 2                   Aedanus Burke
# 3                  Daniel Carroll
# 4                   George Clymer
#
# [5 rows x 34 columns]

# %%
df[df['state']=='AR']['last_name']
# Out:
# 1000       Bates
# 1278      Conway
# 2095      Fulton
# 2253       Cross
# 2317      Sevier
#           ...
# 11529      Berry
# 11600     Snyder
# 11702       Ross
# 11739      Pryor
# 11756    Griffin
# Name: last_name, Length: 117, dtype: object

# %%
df[(df['state']=='WY')&(df['gender']=='F')]
# Out:
#       last_name first_name middle_name suffix nickname          full_name  \
# 11462     Cubin    Barbara          L.    NaN      NaN                NaN
# 11833    Lummis    Cynthia          M.    NaN      NaN  Cynthia M. Lummis
#
#          birthday gender type state  ...  opensecrets_id  lis_id    fec_ids  \
# 11462  1946-11-30      F  rep    WY  ...       N00006242     NaN  H4WY00055
# 11833  1954-09-10      F  rep    WY  ...       N00029788     NaN  H8WY00148
#
#         cspan_id govtrack_id votesmart_id  ballotpedia_id washington_post_id  \
# 11462        NaN      400088      22044.0             NaN                NaN
# 11833  1031365.0      412294      15546.0  Cynthia Lummis                NaN
#
#        icpsr_id    wikipedia_id
# 11462   29584.0   Barbara Cubin
# 11833   20953.0  Cynthia Lummis
#
# [2 rows x 34 columns]

# %%
df2 = df.groupby('state')
print(len(df2.get_group('PA')))#.nunique())
print(len(df2.get_group('NY')))
print(len(df2.get_group('IL')))
print(len(df2.get_group('OH')))
# Out:
# 1053
# 1462
# 486
# 674

# %%
df3 = df.groupby('last_name')
df3.get_group('Abbott').sum()
# Out:
# last_name                          AbbottAbbottAbbottAbbottAbbottAbbott
# first_name                               JoelAmosNehemiahJosephJosiahJo
# suffix                                                                0
# full_name                                                             0
# birthday              1776-03-171786-09-101804-03-291825-07-151814-1...
# gender                                                           MMMMMM
# type                                                 repreprepsenreprep
# state                                                      GAMAMENCMATX
# district                                                             15
# senate_class                                                          2
# party                 RepublicanWhigRepublicanRepublicanDemocratDemo...
# url                                                                   0
# address                                                               0
# phone                                                                 0
# contact_form                                                          0
# rss_url                                                               0
# twitter                                                               0
# facebook                                                              0
# youtube                                                               0
# youtube_id                                                            0
# bioguide_id                  A000003A000004A000008A000006A000007A000005
# thomas_id                                                             0
# opensecrets_id                                                        0
# lis_id                                                                0
# fec_ids                                                               0
# cspan_id                                                              0
# govtrack_id                                                     2404011
# votesmart_id                                                          0
# ballotpedia_id                                                        0
# washington_post_id                                                    0
# icpsr_id                                                             33
# wikipedia_id          Joel Abbot (politician)Amos AbbottNehemiah Abb...
# dtype: object
